# %% [markdown]
# ### Reaplace and interpolate

# %%
import pandas as pd
csv=pd.read_csv("./data_with_missing_values.csv")
csv.interpolate()
# Out:
# /tmp/ipykernel_57017/576472702.py:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   csv.interpolate()
#      id     name   age                email   join_date    country  \
# 0     1    Grace  35.0    user1@example.com  2020-01-05  Australia
# 1     2    David  43.0    user2@example.com  2020-01-12        USA
# 2     3      Eva  61.0    user3@example.com  2020-01-19     Canada
# 3     4    Grace  51.0    user4@example.com  2020-01-26  Australia
# 4     5  Charlie  27.0    user5@example.com  2020-02-02    Germany
# ..  ...      ...   ...                  ...         ...        ...
# 95   96    Frank  39.0   user96@example.com  2021-10-31    Germany
# 96   97      Bob  45.0   user97@example.com  2021-11-07        USA
# 97   98    David  19.0   user98@example.com  2021-11-14        USA
# 98   99    Frank  59.0   user99@example.com  2021-11-21      India
# ...
